# %%
print(t or f)
print(t and f)
print(not t)
print(t !=f)
print(t==f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8aaf003b1bf2> in <module>()
# ----> 1 print(t or f)
#       2 print(t and f)
#       3 print(not t)
#       4 print(t !=f)
#       5 print(t==f)
#
# NameError: name 't' is not defined

# %%
hello='Hello'
world='World'

# %%
print(len(hello))
print(world,)
# Out:
# 5

# %%
print(hello[0])
print(hello[1])
# Out:
# H
# e

# %%
print(hello[-1])
print(hello[-3])
# Out:
# o
# l

# %%
hakan='hakan'

print(hakan[-5])
# Out:
# h

# %%
print(world[3:])
# Out:
# ld

# %%
hello[:4]
# Out:
# 'Hell'

# %%
hello[::-1]
# Out:
# 'olleH'

# %%
world[::-4]
# Out:
# 'dW'

# %%
hello[2:len(world)]
# Out:
# 'llo'

# %%
world[2:4:1]
# Out:
# 'rl'

# %%
city='kayseri'
city[0:6:2]
# Out:
# 'kye'

# %%
't'in city
# Out:
# False

# %%
'y'in city
# Out:
# True

# %%
'anb'in city
# Out:
# False

# %%
'ays'in city
# Out:
# True

# %%
1 n = 10
2 n 
3 str(n)
# Out:
#   File "<ipython-input-24-6a94a9976ab0>", line 1
#     1 n = 10
#       ^
# SyntaxError: invalid syntax

# %%
s = 'kay'
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1007bc524888> in <module>()
#       1 s = 'kay'
# ----> 2 int(s)
#
# ValueError: invalid literal for int() with base 10: 'kay'

# %%
1 world ='machine learning'
2print(world.capitalize())
# Out:
#   File "<ipython-input-28-45febd0ecda4>", line 1
#     1 world ='machine learning'
#           ^
# SyntaxError: invalid syntax

# %%
1 word2='  artificial generel     intelligence'
2 print(word2.strip())
# Out:
#   File "<ipython-input-29-13c5c77fd3ef>", line 1
#     1 word2='  artificial generel     intelligence'
#           ^
# SyntaxError: invalid syntax

# %%
y=input
print(y)
# Out:
# <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7f3846b47eb8>>

# %%
x=int

# %%
1 month=12
2 day=365
3
4 print('Bir yıl'+ str(month))
# Out:
#   File "<ipython-input-31-46c687d50642>", line 1
#     1 month=12
#           ^
# SyntaxError: invalid syntax

# %%
1 # a)Yemek ücretini tanımlayın.
2
 3 cost= 100
4 tax= cost*0.08
5 tip= cost*0.1
6 total=cost + tax + tip
7
8
9
# Out:
#   File "<ipython-input-53-4a7d3aa16cba>", line 3
#     3 cost= 100
#     ^
# IndentationError: unexpected indent

# %%
 mylist=[3,5,6,7]
 print(mylist)
# Out:
# [3, 5, 6, 7]

# %%
mylist[2]='python'
print(mylist)
# Out:
# [3, 5, 'python', 7]

# %%
mylist.appened('course')
print(mylist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-0babfb4cf991> in <module>()
# ----> 1 mylist.appened('course')
#       2 print(mylist)
#
# AttributeError: 'list' object has no attribute 'appened'

# %%
mylist.index('python')
# Out:
# 2

# %%
mylist.sort(str)
mylist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-168fa30e3dc2> in <module>()
# ----> 1 mylist.sort(str)
#       2 mylist
#
# TypeError: must use keyword argument for key function

# %%
mylist.reverse()
mylist
# Out:
# [7, 'python', 5, 3]

# %%
mylist.insert(5,55)
print(mylist)
# Out:
# [7, 'python', 5, 3, 55]

# %%
numbers=list(range(8))

print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
numbers2=list(range(2,14,3))
print(numbers2)
# Out:
# [2, 5, 8, 11]

# %%
print(numbers[2:5])
# Out:
# [2, 3, 4]

# %%
numbers[5:8]=[10,11,12]
numbers
# Out:
# [0, 1, 2, 3, 4, 10, 11, 12]

# %%
[1,2,3]+[4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
[1,2,3]*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
course='python'

s=input('p')

if s in course
   print('Mevcut!')
else:
    print('Yok...')
# Out:
#   File "<ipython-input-67-cd970078edd1>", line 5
#     if s in course
#                   ^
# SyntaxError: invalid syntax
